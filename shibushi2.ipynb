# %%
#import packages 
import pandas as pd 
import numpy as np 
import json 
from  matplotlib import pyplot 
import seaborn as sns 
#create new client instance 
outbound_file0 = pd.read_csv("BNY Mellon Sample Dataset.csv")
outbound_file1 = pd.read_csv("Customer Complaints.csv")

# %%
weishenme!!!
